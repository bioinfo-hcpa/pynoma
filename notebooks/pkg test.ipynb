# %%
from pynoma import RegionSearch

# %%
rs = RegionSearch(3, 4, 1002741, 1002771)

# %%
rs = RegionSearch(3, 4, 987090, 987118)

# %%
normal, clinical = rs.get_data(standard=False)
normal['genome'][0]
# Out:
# {'ac': 1,
#  'ac_hemi': 0,
#  'ac_hom': 0,
#  'an': 143122,
#  'af': 6.987046016685066e-06,
#  'filters': [],
#  'populations': [{'id': 'AFR',
#    'ac': 1,
#    'an': 42014,
#    'ac_hemi': 0,
#    'ac_hom': 0},
#   {'id': 'AMI', 'ac': 0, 'an': 900, 'ac_hemi': 0, 'ac_hom': 0},
#   {'id': 'AMR', 'ac': 0, 'an': 13644, 'ac_hemi': 0, 'ac_hom': 0},
#   {'id': 'ASJ', 'ac': 0, 'an': 3324, 'ac_hemi': 0, 'ac_hom': 0},
#   {'id': 'EAS', 'ac': 0, 'an': 3128, 'ac_hemi': 0, 'ac_hom': 0},
#   {'id': 'FIN', 'ac': 0, 'an': 10412, 'ac_hemi': 0, 'ac_hom': 0},
#   {'id': 'NFE', 'ac': 0, 'an': 64504, 'ac_hemi': 0, 'ac_hom': 0},
#   {'id': 'OTH', 'ac': 0, 'an': 2148, 'ac_hemi': 0, 'ac_hom': 0},
#   {'id': 'SAS', 'ac': 0, 'an': 3048, 'ac_hemi': 0, 'ac_hom': 0}]}

# %%
normal
# Out:
#            consequence flags          gene_id gene_symbol              hgvs  \
# 0     missense_variant    []  ENSG00000127415        IDUA         p.Val2Ala
# 1    inframe_insertion    []  ENSG00000127415        IDUA    p.Leu4_Pro6dup
# 2     missense_variant    []  ENSG00000127415        IDUA         p.Pro3His
# 3   synonymous_variant    []  ENSG00000127415        IDUA         p.Leu4Leu
# 4     missense_variant    []  ENSG00000127415        IDUA         p.Leu4Pro
# 5     missense_variant    []  ENSG00000127415        IDUA         p.Arg5Pro
# 6     missense_variant    []  ENSG00000127415        IDUA         p.Ala5Asp
# 7     missense_variant    []  ENSG00000127415        IDUA         p.Ala7Val
# 8     missense_variant    []  ENSG00000127415        IDUA         p.Ala8Val
# 9     missense_variant    []  ENSG00000127415        IDUA         p.Pro8Gln
# 10   inframe_insertion    []  ENSG00000127415        IDUA  p.Leu13_Ala15dup
# ...

# %%
normal, clinical = rs.get_data()
normal
# Out:
#        Variant ID  Gene         Consequence          Annotation Flags  \
# 0   4-1002747-G-A  IDUA         p.Trp402Ter         stop_gained    []
# 1   4-1002750-C-T  IDUA         p.Ala403Val    missense_variant    []
# 2   4-1002751-C-G  IDUA         p.Ala403Ala  synonymous_variant    []
# 3   4-1002756-T-G  IDUA         p.Val405Gly    missense_variant    []
# 4   4-1002759-C-G  IDUA         p.Ser406Trp    missense_variant    []
# 5   4-1002766-C-T  IDUA         p.Ala408Ala  synonymous_variant    []
# 6   4-1002767-G-C  IDUA         p.Gly409Arg    missense_variant    []
# 7   4-1002768-G-A  IDUA         p.Gly409Glu    missense_variant    []
# 8   4-1002770-A-C  IDUA         p.Thr410Pro    missense_variant    []
# 9  4-1002770-AC-A  IDUA  p.Val411SerfsTer29  frameshift_variant    []
#
#    Allele Count  Allele Number Allele Frequency  Number of Homozygotes
# 0           120         142464     8.423181e-04                      0
# ...

# %%
normal, clinical = rs.get_data(additional_population_info=True)
normal
# Out:
#        Variant ID  Gene         Consequence          Annotation Flags  \
# 0   4-1002747-G-A  IDUA         p.Trp402Ter         stop_gained    []
# 1   4-1002750-C-T  IDUA         p.Ala403Val    missense_variant    []
# 2   4-1002751-C-G  IDUA         p.Ala403Ala  synonymous_variant    []
# 3   4-1002756-T-G  IDUA         p.Val405Gly    missense_variant    []
# 4   4-1002759-C-G  IDUA         p.Ser406Trp    missense_variant    []
# 5   4-1002766-C-T  IDUA         p.Ala408Ala  synonymous_variant    []
# 6   4-1002767-G-C  IDUA         p.Gly409Arg    missense_variant    []
# 7   4-1002768-G-A  IDUA         p.Gly409Glu    missense_variant    []
# 8   4-1002770-A-C  IDUA         p.Thr410Pro    missense_variant    []
# 9  4-1002770-AC-A  IDUA  p.Val411SerfsTer29  frameshift_variant    []
#
#    Allele Count  Allele Number Allele Frequency  Number of Homozygotes  \
# 0           120         142464     8.423181e-04                      0
# ...

# %%
clinical
# Out:
#                             clinical_significance clinvar_variation_id  \
# 0                                    [Pathogenic]                11908
# 1                                    [Pathogenic]               555230
# 2                                    [Pathogenic]               552095
# 3                                 [Likely_benign]               724507
# 4  [Conflicting_interpretations_of_pathogenicity]                92627
# 5                        [Uncertain_significance]               557616
# 6                        [Uncertain_significance]               593572
#
#    gold_stars   major_consequence      pos  \
# 0           2         stop_gained  1002747
# 1           1         stop_gained  1002748
# 2           2         stop_gained  1002752
# 3           1  synonymous_variant  1002766
# 4           1    missense_variant  1002767
# 5           1    missense_variant  1002768
# 6           1    inframe_deletion  1002771
#
#                                  variant_id
# ...

# %%
from pynoma import RegionSearch
rs = RegionSearch(3, 4, 1002741, 1002771)
normal, clinical = rs.get_data(additional_population_info=True)
normal
# Out:
#        Variant ID  Gene         Consequence          Annotation Flags  \
# 0   4-1002747-G-A  IDUA         p.Trp402Ter         stop_gained    []
# 1   4-1002750-C-T  IDUA         p.Ala403Val    missense_variant    []
# 2   4-1002751-C-G  IDUA         p.Ala403Ala  synonymous_variant    []
# 3   4-1002756-T-G  IDUA         p.Val405Gly    missense_variant    []
# 4   4-1002759-C-G  IDUA         p.Ser406Trp    missense_variant    []
# 5   4-1002766-C-T  IDUA         p.Ala408Ala  synonymous_variant    []
# 6   4-1002767-G-C  IDUA         p.Gly409Arg    missense_variant    []
# 7   4-1002768-G-A  IDUA         p.Gly409Glu    missense_variant    []
# 8   4-1002770-A-C  IDUA         p.Thr410Pro    missense_variant    []
# 9  4-1002770-AC-A  IDUA  p.Val411SerfsTer29  frameshift_variant    []
#
#    Allele Count  Allele Number Allele Frequency  Number of Homozygotes  \
# 0           120         142464     8.423181e-04                      0
# ...

# %%
rs = RegionSearch(3, 4, 987000, 987818)
normal, clinical = rs.get_data(standard=False)

# %%
normal
# Out:
#                consequence flags          gene_id gene_symbol        hgvs  \
# 0      5_prime_UTR_variant    []  ENSG00000127415        IDUA    c.-85A>G
# 1      5_prime_UTR_variant    []  ENSG00000127415        IDUA    c.-83A>G
# 2      5_prime_UTR_variant    []  ENSG00000127415        IDUA    c.-82T>G
# 3      5_prime_UTR_variant    []  ENSG00000127415        IDUA    c.-81G>A
# 4      5_prime_UTR_variant    []  ENSG00000127415        IDUA    c.-80G>T
# ..                     ...   ...              ...         ...         ...
# 233    3_prime_UTR_variant    []  ENSG00000145217     SLC26A1  c.*1042G>A
# 234  splice_region_variant    []  ENSG00000127415        IDUA  c.159-8G>A
# 235       missense_variant    []  ENSG00000127415        IDUA  p.Ala53Val
# 236       missense_variant    []  ENSG00000127415        IDUA  p.Pro54His
# 237       missense_variant    []  ENSG00000127415        IDUA  p.Pro55Leu
#
#           hgvsc       hgvsp   lof lof_filter lof_flags     pos          rsid  \
# ...

# %%
count = 0
for f in normal['flags']:
    count +=1
    if f:
        print(f)
        break
        
count
# Out:
# ['lof_flag']
# 47

# %%
normal.iloc[45:, :]
# Out:
#                consequence       flags          gene_id gene_symbol  \
# 45        missense_variant          []  ENSG00000127415        IDUA
# 46      frameshift_variant  [lof_flag]  ENSG00000127415        IDUA
# 47        missense_variant          []  ENSG00000127415        IDUA
# 48        missense_variant          []  ENSG00000127415        IDUA
# 49        missense_variant          []  ENSG00000127415        IDUA
# ..                     ...         ...              ...         ...
# 233    3_prime_UTR_variant          []  ENSG00000145217     SLC26A1
# 234  splice_region_variant          []  ENSG00000127415        IDUA
# 235       missense_variant          []  ENSG00000127415        IDUA
# 236       missense_variant          []  ENSG00000127415        IDUA
# 237       missense_variant          []  ENSG00000127415        IDUA
#
#                   hgvs       hgvsc              hgvsp   lof lof_filter  \
# 45          p.Ala20Val     c.59C>T         p.Ala20Val  None       None
# ...

# %%
rs = RegionSearch(3, 4, 987000, 987818)
normal, clinical = rs.get_data(standard=False)

# %%
normal.iloc[46:47, :]['genome'][46]
# Out:
# {'ac': 1,
#  'ac_hemi': 0,
#  'ac_hom': 0,
#  'an': 143154,
#  'af': 6.985484163907401e-06,
#  'filters': [],
#  'populations': [{'id': 'AFR',
#    'ac': 0,
#    'an': 42026,
#    'ac_hemi': 0,
#    'ac_hom': 0},
#   {'id': 'AMI', 'ac': 0, 'an': 900, 'ac_hemi': 0, 'ac_hom': 0},
#   {'id': 'AMR', 'ac': 0, 'an': 13644, 'ac_hemi': 0, 'ac_hom': 0},
#   {'id': 'ASJ', 'ac': 0, 'an': 3324, 'ac_hemi': 0, 'ac_hom': 0},
#   {'id': 'EAS', 'ac': 0, 'an': 3130, 'ac_hemi': 0, 'ac_hom': 0},
#   {'id': 'FIN', 'ac': 0, 'an': 10410, 'ac_hemi': 0, 'ac_hom': 0},
#   {'id': 'NFE', 'ac': 1, 'an': 64518, 'ac_hemi': 0, 'ac_hom': 0},
#   {'id': 'OTH', 'ac': 0, 'an': 2152, 'ac_hemi': 0, 'ac_hom': 0},
#   {'id': 'SAS', 'ac': 0, 'an': 3050, 'ac_hemi': 0, 'ac_hom': 0}]}

# %%
normal
# Out:
#                consequence flags          gene_id gene_symbol        hgvs  \
# 0      5_prime_UTR_variant    []  ENSG00000127415        IDUA    c.-85A>G
# 1      5_prime_UTR_variant    []  ENSG00000127415        IDUA    c.-83A>G
# 2      5_prime_UTR_variant    []  ENSG00000127415        IDUA    c.-82T>G
# 3      5_prime_UTR_variant    []  ENSG00000127415        IDUA    c.-81G>A
# 4      5_prime_UTR_variant    []  ENSG00000127415        IDUA    c.-80G>T
# ..                     ...   ...              ...         ...         ...
# 233    3_prime_UTR_variant    []  ENSG00000145217     SLC26A1  c.*1042G>A
# 234  splice_region_variant    []  ENSG00000127415        IDUA  c.159-8G>A
# 235       missense_variant    []  ENSG00000127415        IDUA  p.Ala53Val
# 236       missense_variant    []  ENSG00000127415        IDUA  p.Pro54His
# 237       missense_variant    []  ENSG00000127415        IDUA  p.Pro55Leu
#
#           hgvsc       hgvsp   lof lof_filter lof_flags     pos          rsid  \
# ...
