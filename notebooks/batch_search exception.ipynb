# %%
from pynoma import RegionSearch
import pandas as pd

from random import randint, uniform
from time import sleep

# %%
# search_objects: a list of Search objects different from VariantSearch, i.e,
# a list of GeneSearch, RegionSearch and/or TranscriptSearch objects
def batch_search(search_objects, standard=True, additional_population_info=False):
    datasets=[]
    for obj in search_objects:
        try:
            obj_df, _ = obj.get_data(standard=standard, additional_population_info=additional_population_info) 
            if isinstance(obj_df, pd.DataFrame):
                datasets.append(obj_df)
        except Exception as e:
            print(obj.chromosome, obj.start, obj.end)
            if type(e).__name__ == 'KeyError':
                sleep(30)#randint(10,10))
                obj_df, _ = obj.get_data(standard=standard, additional_population_info=additional_population_info) 
                if isinstance(obj_df, pd.DataFrame):
                    datasets.append(obj_df)
            else:
                raise(e)
    return pd.concat(datasets)#.fillna(0)

# %%
s = [RegionSearch(3,1,146766543,146766543),
RegionSearch(3,1,43261323,43261323),
RegionSearch(3,1,17120642,17120642),
RegionSearch(3,1,24697316,24697316),
RegionSearch(3,1,107254440,107254440),
RegionSearch(3,1,233395764,233395764),
RegionSearch(3,1,65420726,65420726),
RegionSearch(3,1,228736137,228736137),
RegionSearch(3,1,81615623,81615623),
RegionSearch(3,1,105115964,105115964),
RegionSearch(3,1,121510389,121510389),
RegionSearch(3,1,117337943,117337943),
RegionSearch(3,1,75759049,75759049),
RegionSearch(3,1,154671969,154671969),
RegionSearch(3,1,87431288,87431288),
RegionSearch(3,1,24491022,24491022),
RegionSearch(3,1,58167720,58167720),
RegionSearch(3,1,162434418,162434418),
RegionSearch(3,1,62762631,62762631),
RegionSearch(3,1,171305378,171305378),
RegionSearch(3,1,229180706,229180706),
RegionSearch(3,1,96140532,96140532),
RegionSearch(3,1,177326092,177326092),
RegionSearch(3,1,245885163,245885163)]

s2 = [RegionSearch(3,1,146766543,146766543),
RegionSearch(3,1,43261323,43261323),
RegionSearch(3,1,17120642,17120642),
RegionSearch(3,1,24697316,24697316),
RegionSearch(3,1,107254440,107254440),
RegionSearch(3,1,233395764,233395764),
RegionSearch(3,1,65420726,65420726),
RegionSearch(3,1,228736137,228736137),
RegionSearch(3,1,81615623,81615623),
RegionSearch(3,1,105115964,105115964),
RegionSearch(3,1,121510389,121510389),
RegionSearch(3,1,117337943,117337943),
RegionSearch(3,1,75759049,75759049),
RegionSearch(3,1,154671969,154671969),
RegionSearch(3,1,87431288,87431288),
RegionSearch(3,1,24491022,24491022),
RegionSearch(3,1,58167720,58167720),
RegionSearch(3,1,162434418,162434418),
RegionSearch(3,1,62762631,62762631),
RegionSearch(3,1,171305378,171305378),
RegionSearch(3,1,229180706,229180706),
RegionSearch(3,1,96140532,96140532),
RegionSearch(3,1,177326092,177326092),
RegionSearch(3,1,245885163,245885163),
RegionSearch(3,1,178976173,178976173),
RegionSearch(3,1,79594306,79594306),
RegionSearch(3,1,80584220,80584220),
RegionSearch(3,1,84903278,84903278),
RegionSearch(3,1,80584323,80584323),
RegionSearch(3,1,177325989,177325989),
RegionSearch(3,1,245885060,245885060),
RegionSearch(3,1,167494434,167494434),
RegionSearch(3,1,177181802,177181802),
RegionSearch(3,1,117579836,117579836),
RegionSearch(3,1,74740334,74740334),
RegionSearch(3,1,29982449,29982449),
RegionSearch(3,1,215394037,215394037),
RegionSearch(3,1,188263402,188263402),
RegionSearch(3,1,214275554,214275554),
RegionSearch(3,1,147517641,147517641),
RegionSearch(3,1,110395474,110395474),
RegionSearch(3,1,192895496,192895496),
RegionSearch(3,1,197069187,197069187),
RegionSearch(3,1,102749820,102749820),
RegionSearch(3,1,145795141,145795141),
RegionSearch(3,1,231641230,231641230),
RegionSearch(3,1,8153125,8153125),
RegionSearch(3,1,232314036,232314036),
RegionSearch(3,1,116297256,116297256),
RegionSearch(3,1,207370623,207370623),
RegionSearch(3,1,218508082,218508082),
RegionSearch(3,1,194430444,194430444),
RegionSearch(3,1,81177839,81177839),
RegionSearch(3,1,194357698,194357698),
RegionSearch(3,1,241854773,241854773),
RegionSearch(3,1,244681924,244681924),
RegionSearch(3,1,195722026,195722026),
RegionSearch(3,1,185647991,185647991),
RegionSearch(3,1,189717592,189717592),
RegionSearch(3,1,89127074,89127074),
RegionSearch(3,1,89272507,89272507),
RegionSearch(3,1,153011029,153011029),
RegionSearch(3,1,194616812,194616812),
RegionSearch(3,1,158348178,158348178),
RegionSearch(3,1,86809322,86809322),
RegionSearch(3,1,105097622,105097622),
RegionSearch(3,1,187072656,187072656),
RegionSearch(3,1,155306767,155306767),
RegionSearch(3,1,74247107,74247107),
RegionSearch(3,1,238683668,238683668),
RegionSearch(3,1,232870675,232870675),
RegionSearch(3,1,193304930,193304930),
RegionSearch(3,1,115361418,115361418),
RegionSearch(3,1,158373186,158373186),
RegionSearch(3,1,59968857,59968857),
RegionSearch(3,1,112853744,112853744),
RegionSearch(3,1,6395130,6395130),
RegionSearch(3,1,188012536,188012536),
RegionSearch(3,1,176348594,176348594),
RegionSearch(3,1,214672338,214672338),
RegionSearch(3,1,154531359,154531359),
RegionSearch(3,1,157445493,157445493),
RegionSearch(3,1,174280840,174280840),
RegionSearch(3,1,237308538,237308538),
RegionSearch(3,1,102743926,102743926),
RegionSearch(3,1,54003272,54003272),
RegionSearch(3,1,174055588,174055588),
RegionSearch(3,1,51846505,51846505),
RegionSearch(3,1,79560615,79560615),
RegionSearch(3,1,19983756,19983756),
RegionSearch(3,1,192988024,192988024),
RegionSearch(3,1,169669380,169669380),
RegionSearch(3,1,169883216,169883216),
RegionSearch(3,1,196810082,196810082),
RegionSearch(3,1,93171385,93171385),
RegionSearch(3,1,235141949,235141949),
RegionSearch(3,1,208740890,208740890),
RegionSearch(3,1,194860216,194860216),
RegionSearch(3,1,198405368,198405368),
RegionSearch(3,1,228774819,228774819),
RegionSearch(3,1,233466617,233466617),
RegionSearch(3,1,59473462,59473462),
RegionSearch(3,1,225432714,225432714),
RegionSearch(3,1,154679282,154679282),
RegionSearch(3,1,231318178,231318178),
RegionSearch(3,1,246713075,246713075),
RegionSearch(3,1,226465103,226465103),
RegionSearch(3,1,174712610,174712610),
RegionSearch(3,1,57693735,57693735),
RegionSearch(3,1,151273047,151273047),
RegionSearch(3,1,195055616,195055616),
RegionSearch(3,1,220413476,220413476),
RegionSearch(3,1,194003014,194003014),
RegionSearch(3,1,188814498,188814498),
RegionSearch(3,1,161473186,161473186),
RegionSearch(3,1,119180363,119180363),
RegionSearch(3,1,192912347,192912347),
RegionSearch(3,1,179139493,179139493),
RegionSearch(3,1,1108015,1108015),
RegionSearch(3,1,229866792,229866792),
RegionSearch(3,1,46401398,46401398),
RegionSearch(3,1,74466217,74466217),
RegionSearch(3,1,117173219,117173219),
RegionSearch(3,1,187851435,187851435),
RegionSearch(3,1,86807532,86807532),
RegionSearch(3,1,225473869,225473869),
RegionSearch(3,1,187704824,187704824),
RegionSearch(3,1,11609890,11609890),
RegionSearch(3,1,199960697,199960697),
RegionSearch(3,1,222050959,222050959),
RegionSearch(3,1,150900338,150900338),
RegionSearch(3,1,173376997,173376997),
RegionSearch(3,1,2846909,2846909),
RegionSearch(3,1,1751441,1751441),
RegionSearch(3,1,1698831,1698831),
RegionSearch(3,1,199612,199612),
RegionSearch(3,1,29096,29096),
RegionSearch(3,1,27546263,27546263),
RegionSearch(3,1,38012828,38012828),
RegionSearch(3,1,119631769,119631769),
RegionSearch(3,1,1685547,1685547),
RegionSearch(3,1,43604948,43604948),
RegionSearch(3,1,214331818,214331818),
RegionSearch(3,1,105115861,105115861),
RegionSearch(3,1,148246059,148246059),
RegionSearch(3,1,12616169,12616169),
RegionSearch(3,1,1228478,1228478),
RegionSearch(3,1,1965117,1965117),
RegionSearch(3,1,37030322,37030322),
RegionSearch(3,1,111989656,111989656),
RegionSearch(3,1,155609977,155609977),
RegionSearch(3,1,155745559,155745559),
RegionSearch(3,1,248165123,248165123),
RegionSearch(3,1,7073092,7073092),
RegionSearch(3,1,61453744,61453744),
RegionSearch(3,1,1819034,1819034),
RegionSearch(3,1,229558480,229558480),
RegionSearch(3,1,234600288,234600288),
RegionSearch(3,1,23202004,23202004),
RegionSearch(3,1,1041869,1041869),
RegionSearch(3,1,228643307,228643307),
RegionSearch(3,1,228618730,228618730),
RegionSearch(3,1,228627646,228627646),
RegionSearch(3,1,228612007,228612007),
RegionSearch(3,1,228636594,228636594),
RegionSearch(3,1,228557784,228557784),
RegionSearch(3,1,228623165,228623165),
RegionSearch(3,1,228625407,228625407),
RegionSearch(3,1,228629888,228629888),
RegionSearch(3,1,228645538,228645538),
RegionSearch(3,1,228641066,228641066),
RegionSearch(3,1,228614248,228614248),
RegionSearch(3,1,228632129,228632129),
RegionSearch(3,1,228609766,228609766),
RegionSearch(3,1,228638835,228638835),
RegionSearch(3,1,228634369,228634369),
RegionSearch(3,1,228616489,228616489),
RegionSearch(3,1,116152193,116152193),
RegionSearch(3,1,203681612,203681612),
RegionSearch(3,1,152515771,152515771),
RegionSearch(3,1,214870617,214870617),
RegionSearch(3,1,212608483,212608483),
RegionSearch(3,1,204006429,204006429),
RegionSearch(3,1,13165596,13165596),
RegionSearch(3,1,13116529,13116529)
]

# %%
df = batch_search(s)
# Out:
# No variants found.
# No variants found.
# No variants found.
# No variants found.
# No variants found.
# No variants found.
# No variants found.
# No variants found.
# No variants found.
# No variants found.
# 1 87431288 87431288
# No variants found.
# No variants found.
# No variants found.
# No variants found.

# %%
# search_objects: a list of Search objects different from VariantSearch, i.e,
# a list of GeneSearch, RegionSearch and/or TranscriptSearch objects
def batch_search(search_objects, standard=True, additional_population_info=False):
    datasets=[]
    for obj in search_objects:
        try:
            obj_df, _ = obj.get_data(standard=standard, additional_population_info=additional_population_info) 
            if isinstance(obj_df, pd.DataFrame):
                datasets.append(obj_df)
        except Exception as e:
            print(obj.chromosome, obj.start, obj.end)
            if type(e).__name__ == 'KeyError':
                sleep(30)#randint(10,10))
                obj_df, _ = obj.get_data(standard=standard, additional_population_info=additional_population_info) 
                if isinstance(obj_df, pd.DataFrame):
                    datasets.append(obj_df)
            else:
                raise(e)
    return pd.concat(datasets)#.fillna(0)

# %%
df = batch_search(s2)
# Out:
# No variants found.
# No variants found.
# No variants found.
# No variants found.
# No variants found.
# No variants found.
# No variants found.
# No variants found.
# No variants found.
# No variants found.
# 1 87431288 87431288
# No variants found.
# No variants found.
# No variants found.
# No variants found.
# No variants found.
# No variants found.
# No variants found.
# 1 80584323 80584323
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-54-d1eca50ea495> in batch_search(search_objects, standard, additional_population_info)
#       6         try:
# ----> 7             obj_df, _ = obj.get_data(standard=standard, additional_population_info=additional_population_info)
#       8             if isinstance(obj_df, pd.DataFrame):
#
# ~/Documents/pynoma/pynoma/Search.py in get_data(self, standard, additional_population_info)
# ...

# %%
# search_objects: a list of Search objects different from VariantSearch, i.e,
# a list of GeneSearch, RegionSearch and/or TranscriptSearch objects
def batch_search(search_objects, standard=True, additional_population_info=False):
    datasets=[]
    for i, obj in enumerate(search_objects):
        print("Search number", i)
        sleep(uniform(1,5))
        try:
            obj_df, _ = obj.get_data(standard=standard, additional_population_info=additional_population_info) 
            if isinstance(obj_df, pd.DataFrame):
                datasets.append(obj_df)
        except Exception as e:
            print(obj.chromosome, obj.start, obj.end)
            if type(e).__name__ == 'KeyError':
                sleep(30)#randint(10,10))
                obj_df, _ = obj.get_data(standard=standard, additional_population_info=additional_population_info) 
                if isinstance(obj_df, pd.DataFrame):
                    datasets.append(obj_df)
            else:
                raise(e)
    return pd.concat(datasets)#.fillna(0)

# %%
df = batch_search(s2)
# Out:
# Search number 0
# No variants found.
# Search number 1
# No variants found.
# Search number 2
# Search number 3
# No variants found.
# Search number 4
# No variants found.
# Search number 5
# No variants found.
# Search number 6
# No variants found.
# Search number 7
# No variants found.
# Search number 8
# Search number 9
# No variants found.
# Search number 10
# Search number 11
# Search number 12
# No variants found.
# Search number 13
# No variants found.
# Search number 14
# No variants found.
# Search number 15
# Search number 16
# No variants found.
# Search number 17
# Search number 18
# Search number 19
# Search number 20
# Search number 21
# 1 96140532 96140532
# No variants found.
# Search number 22
# Search number 23
# No variants found.
# Search number 24
# No variants found.
# Search number 25
# No variants found.
# Search number 26
# Search number 27
# No variants found.
# Search number 28
# Search number 29
# No variants found.
# Search number 30
# Search number 31
# ...
