# %%
from pynoma import GeneSearch
gs = GeneSearch(3, "idua")
df, _ = gs.get_data()
df
# Out:
#            Variant ID  Gene   Consequence           Annotation Flags  \
# 0        4-987010-C-G  IDUA      c.-75C>G  5_prime_UTR_variant    []
# 1        4-987013-G-A  IDUA      c.-72G>A  5_prime_UTR_variant    []
# 2        4-987014-C-T  IDUA      c.-71C>T  5_prime_UTR_variant    []
# 3        4-987021-T-C  IDUA      c.-64T>C  5_prime_UTR_variant    []
# 4        4-987023-C-G  IDUA      c.-62C>G  5_prime_UTR_variant    []
# ...               ...   ...           ...                  ...   ...
# 1199    4-1004450-G-A  IDUA      c.*57G>A  3_prime_UTR_variant    []
# 1200  4-1004450-G-GCA  IDUA  c.*59_*60dup  3_prime_UTR_variant    []
# 1201    4-1004452-A-C  IDUA      c.*59A>C  3_prime_UTR_variant    []
# 1202    4-1004458-C-G  IDUA      c.*65C>G  3_prime_UTR_variant    []
# 1203    4-1004459-C-G  IDUA      c.*66C>G  3_prime_UTR_variant    []
#
#       Allele Count  Allele Number  Allele Frequency  Number of Homozygotes  \
# ...

# %% [markdown]
# ## Plots

# %%
from matplotlib import style
import seaborn as sns; sns.set()
style.use('fivethirtyeight')
sns.set_palette("hls", len(df['Annotation'].value_counts().index))
ax = sns.countplot(y="Annotation", data=df, order=df['Annotation'].value_counts().index)

# %%
sns.boxplot(data=df, x="Allele Frequency", y="Annotation")
# Out:
# <AxesSubplot:xlabel='Allele Frequency', ylabel='Annotation'>

# %% [markdown]
# ## Batch search

# %%
from pynoma import GeneSearch
import pandas as pd

searches = [GeneSearch(3,"idua"), GeneSearch(3,"ace2"), GeneSearch(3,"mmp11"), GeneSearch(3,"id4")]

# %%
datasets=[]
for s in searches:
    s_df, _ = s.get_data() 
    datasets.append(s_df)

# %%
pd.concat(datasets).fillna(0)
# Out:
#          Variant ID  Gene  Consequence           Annotation Flags  \
# 0      4-987010-C-G  IDUA     c.-75C>G  5_prime_UTR_variant    []
# 1      4-987013-G-A  IDUA     c.-72G>A  5_prime_UTR_variant    []
# 2      4-987014-C-T  IDUA     c.-71C>T  5_prime_UTR_variant    []
# 3      4-987021-T-C  IDUA     c.-64T>C  5_prime_UTR_variant    []
# 4      4-987023-C-G  IDUA     c.-62C>G  5_prime_UTR_variant    []
# ..              ...   ...          ...                  ...   ...
# 368  6-19838689-C-G   ID4  c.*14+47C>G       intron_variant    []
# 369  6-19838690-G-C   ID4  c.*14+48G>C       intron_variant    []
# 370  6-19838690-G-A   ID4  c.*14+48G>A       intron_variant    []
# 371  6-19838694-C-T   ID4  c.*14+52C>T       intron_variant    []
# 372  6-19838700-G-T   ID4  c.*14+58G>T       intron_variant    []
#
#      Allele Count  Allele Number  Allele Frequency  Number of Homozygotes  \
# 0               1         149172          0.000007                      0
# ...
